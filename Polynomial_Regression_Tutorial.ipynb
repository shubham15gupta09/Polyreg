# %% [markdown]
# <a href="https://colab.research.google.com/github/shubham15gupta09/Polyreg/blob/master/Polynomial_Regression_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > # **A Tutorial on the Polynomial Regression**
# ______________________________________________
#
# ---
#
# \\
#
# >   ### *Polynomial Regression is the first step to learn Machine Learning.*
#
# \\
# This is a simple tutorial about the Polynomial Regression becuase It is an important subject to learn **Machine Learning** and it is also an important subject for **Mathematics and Computing**  as well. So, Here I have described some basic things and important things about the Polynominal Regresstion mainly used in the Machine Learning and Computing. I have also added some examples of polynominal regression and it's advantages and Disadvantages. This tutorial will help you learn the *Basic* of Polynominal Regression in a simple way so that anyone can learn the Polynominal Regression Easily.
#
# \\
#
#
# \\
# ##**Defination of Polynominal :**
# ----------------------------------------------
#
# \\
# We all are familiar with the word **Polynomial**. It is a word commonly and widely used in the field of *Mathematics* which includes *Algebra . Polynominals have one or more variables like
#
# \\
#
# $$x^2 + y +z   \   , \ -2z+v^4=21$$
#
# \\
# But we have to be careful that the  variables can't be in the denominations of the fraction or under the square root. The below examples are not the polynominals
#
# \\
# $$\sqrt{x^3-y^3} \ , \ \frac{2}{x}$$
#
# \\
#
# ---
#
#
# > ### "*Polynominal Regression is An analysis which is a form of predictive modelling technique which investigates the relationship between dependent variable $y$ and independent variable $x$ is modelled as an $n^{th}$ degree Polynominal "*
#
# ---
#
# \\
#
#
#
# Now here comes the question, **What is the Benefit of Using the Polynominal Regression ?**
#
# The answer is there are many advantages or benefits of using the polynomial regression and Some of the main benefits are -
#
# \\
# **(1)** Polynominal usually fits a wide range of curvature and it is the most important in the theoretical one. There are some relationships that the recent researchers are going to hypotize that it is a curvilinear.
#
# \\
# **(2)**Also a broad range of fuction can be fit under it.
#
# \\
# **(3)** Polynomials provide the best *Approximation* of the relationship between the dependent and independent variable.
#
# \\
# **(4)** A Simple  scattered plot can easily reveal a curvilinear realtionship which is one of the good advantages of Polynominal Repression.
#
#
# \\
# But However there are some *disadvantages* of using the polynominal regression because these polynominals are too sensitive to the outliers and besides that there are a very few model validation tools for the detection of outliers in nonlinear regression than    there are for linear regression which is a very much unfortunate.
#
# \\
#
# #History of Polynominal Regression :
# ---
# \\
#
# There is a history behind the inovation of *Polynominal Regression*. Some people used to say that there was the use of polynomial regression in the  mid $18 th$ century but it was widely unknown to everyone. This Polynominal Regression models generally fit using the least square. The least square method is a standard approach in regression analaysis to approximate the solution of overdetermined systems by minimizng the sum of the squares of the residuals made in the results of every single equation and The data fitiing is the most essential application. In $1805$ the least squares method was published by the reknowned Mathematician Legendrea and agian this least square theorem was also proposed by the mathematician Guass but the first desgin of an experiment for polynominal regression appeared in a paper named *Gergonne*.
#
# Since then there were many uses of Polynominal Regression in many aspects of approximation and analaysis. As a result this played an important role in the development of regresion analaysis with a greater emphasis on issues of design and inference.
#
# Still Now there are many uses of Polynominal Regression in this century. Especially, Polynominal Regression plays the main role in the aspects of Machine Learnnig.
#
# \\
#
#
# #Polynominal Regression Model
# ---
#
# \\
#
# The model of polynominal Regression is
#
# \\
#
# $$y_1 = \beta_0 + \beta_1x_i + \beta_2x^2_i + \cdots + \beta_mx^m_i + \varepsilon_i\ (i = 1,2,\cdots , n) $$
#
# \\
#
# and this model can be expressed in martix form in terms of a desgin martix $\mathbf{X}$ which is a response vector $\vec y$, a parameter vector $\vec \beta$ and a vector $\vec\varepsilon$ of random errors. The $i^{th}$ row of $\mathbf{X}$ and $\vec y$ will contain the $x$ and $y$ value for the $i$th data sample. Then the model can be written as a system of linear equations
#
# \\
#
#
# \\
#
#
#
#
# \\
#
# ### Python Code For Polynomial Regression
#  ---
#
#  \\
#
# Here is an example of implementing the Polynominal Regression by the Python Code. the python code will automatically generates the graph of the Polynominal regression for the Visuallization if we plot or inpute the proper data into our python code
#
# \\
#
# In this Section of the tutorial I have presented a Sample Data for the example of the Polynominal Regression. The datas are given below :
#
# \\
#
#  | Position | Level | Salary
#  |:---|:---:|---:
# Business Analyst| 1| 45000
# Junior Consultant |2 |50000
# Senior Consultant |3 |60000
# Manager |4| 80000
# Country Manager |5| 110000
# Region Manager |6| 150000
# Partner |7| 200000
# Senior Partner |8| 300000
# C­level |9| 500000
# CEO |10| 1000000
#
# \\
#
# Now The python code for implementing this data into the graph of Polynominal Regression for Visualization is given Below :
#
# \\
#
# ```
# import numpy as np
# import matplotlib.pyplot as plt
# import pandas as pd
#
# # Importing the dataset
# dataset = pd.read_csv('data.csv')
# X = dataset.iloc[:, 1:2].values
# y = dataset.iloc[:, 2].values
#
# # Fitting Linear Regression to the dataset
# from sklearn.linear_model import LinearRegression
# lin = LinearRegression()
#
# lin.fit(X, y)
#
# # Fitting Polynomial Regression to the dataset
# from sklearn.preprocessing import PolynomialFeatures
#
# poly = PolynomialFeatures(degree = 4)
# X_poly = poly.fit_transform(X)
#
# poly.fit(X_poly, y)
# lin2 = LinearRegression()
# lin2.fit(X_poly, y)
#
# # Visualising the Linear Regression results
# plt.scatter(X, y, color = 'blue')
#
# plt.plot(X, lin.predict(X), color = 'red')
# plt.title('Linear Regression')
# plt.xlabel('Salary')
# plt.ylabel('Position')
#
# plt.show()
#
#
# # Visualising the Polynomial Regression results
# plt.scatter(X, y, color = 'blue')
#
# plt.plot(X, lin2.predict(poly.fit_transform(X)), color = 'red')
# plt.title('Polynomial Regression')
# plt.xlabel('Salary')
# plt.ylabel('Position')
#
# plt.show()
#
#
# # Predicting a new result with Linear Regression
# lin.predict(110.0)
#
#
# # Predicting a new result with Polynomial Regression
# lin2.predict(poly.fit_transform(110.0))
#
# ```
#
# \\
#
# \\
#
# # Summary of this Tutorial
# ---
#
# \\
#
# In this article, I have discussed about the Polynominal Regression and the advantages of the polynominal regression and the history of the Polynominal Regression and its implemention of it by python code.
#
# I have wrote a python code for the Visualization of the polynominal Regression with an example of sample data.
#
#  >> I explained about Polynominal and Polynominal  Regression with simple and clear understanding so that everyone has easily learn the important topics and aspects of Polynominal Regression very quickly.
#
#
# \\
#
# #Reference and Acknowledgement
# ---
#
# \\
#
# **[1]** Polynomial Regression, Wikipedia, https://en.m.wikipedia.org/wiki/Polynomial_regression
#
# \\
# **[2]** Python Implementation of Polynominal Regression, (https://www.geeksforgeeks.org/python-implementation-of-polynomial-regression/.com)
#
# \\
# **[3]** Machine Learning Polynominal Reg https://towardsdatascience.com/machine-learning-polynomial-regression-with-python-5328e4e8a386

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv("https://drive.google.com/file/d/1tNL4jxZEfpaP4oflfSn6pIHJX7Pachm9/view")
X = dataset.iloc[:, 1:2].values
y = dataset.iloc[:, 2].values


# Fitting Linear Regression to the dataset 
from sklearn.linear_model import LinearRegression 
lin = LinearRegression() 
  
lin.fit(X, y) 

# Fitting Polynomial Regression to the dataset 
from sklearn.preprocessing import PolynomialFeatures 
  
poly = PolynomialFeatures(degree = 4) 
X_poly = poly.fit_transform(X) 
  
poly.fit(X_poly, y) 
lin2 = LinearRegression() 
lin2.fit(X_poly, y) 
 
# Visualising the Linear Regression results 
plt.scatter(X, y, color = 'blue') 
  
plt.plot(X, lin.predict(X), color = 'red') 
plt.title('Linear Regression') 
plt.xlabel('Salary') 
plt.ylabel('Position') 
  
plt.show() 

 
# Visualising the Polynomial Regression results 
plt.scatter(X, y, color = 'blue') 
  
plt.plot(X, lin2.predict(poly.fit_transform(X)), color = 'red') 
plt.title('Polynomial Regression') 
plt.xlabel('Salary') 
plt.ylabel('Position') 
  
plt.show() 

 
# Predicting a new result with Linear Regression 
lin.predict(110.0) 


# Predicting a new result with Polynomial Regression 
lin2.predict(poly.fit_transform(110.0))
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-4-b14d43e2515b> in <module>()
#       4
#       5 # Importing the dataset
# ----> 6 dataset = pd.read_csv("https://drive.google.com/file/d/1tNL4jxZEfpaP4oflfSn6pIHJX7Pachm9/view")
#       7 X = dataset.iloc[:, 1:2].values
#       8 y = dataset.iloc[:, 2].values
#
# ...
